# %%
#Importing library
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Position_Salaries.csv")
df
# Out:
#             Position  Level     Salary
# 0   Business Analyst    NaN    45000.0
# 1  Junior Consultant    2.0        NaN
# 2  Senior Consultant    3.0    60000.0
# 3            Manager    NaN    80000.0
# 4    Country Manager    5.0   110000.0
# 5     Region Manager    6.0   150000.0
# 6            Partner    7.0   200000.0
# 7     Senior Partner    8.0        NaN
# 8            C-level    NaN   500000.0
# 9                NaN   10.0  1000000.0

# %%
new_df = df.fillna({
    "Position":"No Position",
    "Level": 0,
    "Salary": 0
})

# %%
new_df
# Out:
#             Position  Level     Salary
# 0   Business Analyst    0.0    45000.0
# 1  Junior Consultant    2.0        0.0
# 2  Senior Consultant    3.0    60000.0
# 3            Manager    0.0    80000.0
# 4    Country Manager    5.0   110000.0
# 5     Region Manager    6.0   150000.0
# 6            Partner    7.0   200000.0
# 7     Senior Partner    8.0        0.0
# 8            C-level    0.0   500000.0
# 9        No Position   10.0  1000000.0

# %%
df_2 = df.interpolate()
df_2
# Out:
#             Position  Level     Salary
# 0   Business Analyst    NaN    45000.0
# 1  Junior Consultant    2.0    52500.0
# 2  Senior Consultant    3.0    60000.0
# 3            Manager    4.0    80000.0
# 4    Country Manager    5.0   110000.0
# 5     Region Manager    6.0   150000.0
# 6            Partner    7.0   200000.0
# 7     Senior Partner    8.0   350000.0
# 8            C-level    9.0   500000.0
# 9                NaN   10.0  1000000.0

# %%
df_2 = df.dropna()
df_2
# Out:
#             Position  Level    Salary
# 2  Senior Consultant    3.0   60000.0
# 4    Country Manager    5.0  110000.0
# 5     Region Manager    6.0  150000.0
# 6            Partner    7.0  200000.0

# %%
df_3 = pd.read_csv("Pandas_group.csv")
df_3
# Out:
#           Day        City  Tempreature  Windspeed   Event
# 0    1/1/2017  Chandigarh           32          6    Rain
# 1    1/2/2017  Chandigarh           36          7   Sunny
# 2    1/3/2017  Chandigarh           28         12    Snow
# 3    1/4/2017        Pune           33          7   Sunny
# 4    1/5/2017        Pune           90          5   Sunny
# 5    1/6/2017        Pune           85         12     Fog
# 6    1/7/2017        Pune           87         15     Fog
# 7    1/8/2017     Mathura           92          5    Rain
# 8    1/9/2017     Mathura           45         20   Sunny
# 9   1/10/2017     Mathura           50         13  Cloudy
# 10  1/11/2017     Mathura           54          8  Cloudy

# %%
a = df_3.groupby("City")        #using group function
a

# %%
for i,j in a:
    print(i)
    print(j,"\n")
# Out:
# Chandigarh
#         Day        City  Tempreature  Windspeed  Event
# 0  1/1/2017  Chandigarh           32          6   Rain
# 1  1/2/2017  Chandigarh           36          7  Sunny
# 2  1/3/2017  Chandigarh           28         12   Snow
#
# Mathura
#           Day     City  Tempreature  Windspeed   Event
# 7    1/8/2017  Mathura           92          5    Rain
# 8    1/9/2017  Mathura           45         20   Sunny
# 9   1/10/2017  Mathura           50         13  Cloudy
# 10  1/11/2017  Mathura           54          8  Cloudy
#
# Pune
#         Day  City  Tempreature  Windspeed  Event
# 3  1/4/2017  Pune           33          7  Sunny
# 4  1/5/2017  Pune           90          5  Sunny
# 5  1/6/2017  Pune           85         12    Fog
# 6  1/7/2017  Pune           87         15    Fog

# %%
a.get_group("Chandigarh")
# Out:
#         Day        City  Tempreature  Windspeed  Event
# 0  1/1/2017  Chandigarh           32          6   Rain
# 1  1/2/2017  Chandigarh           36          7  Sunny
# 2  1/3/2017  Chandigarh           28         12   Snow

# %%
a.max()
# Out:
#                  Day  Tempreature  Windspeed  Event
# City
# Chandigarh  1/3/2017           36         12  Sunny
# Mathura     1/9/2017           92         20  Sunny
# Pune        1/7/2017           90         15  Sunny

# %%
a.mean()
# Out:
#             Tempreature  Windspeed
# City
# Chandigarh        32.00   8.333333
# Mathura           60.25  11.500000
# Pune              73.75   9.750000

# %%
a.describe()
# Out:
#            Tempreature                                                    \
#                  count   mean        std   min    25%   50%    75%   max
# City
# Chandigarh         3.0  32.00   4.000000  28.0  30.00  32.0  34.00  36.0
# Mathura            4.0  60.25  21.484491  45.0  48.75  52.0  63.50  92.0
# Pune               4.0  73.75  27.244265  33.0  72.00  86.0  87.75  90.0
#
#            Windspeed
#                count       mean       std  min   25%   50%    75%   max
# City
# Chandigarh       3.0   8.333333  3.214550  6.0  6.50   7.0   9.50  12.0
# Mathura          4.0  11.500000  6.557439  5.0  7.25  10.5  14.75  20.0
# Pune             4.0   9.750000  4.573474  5.0  6.50   9.5  12.75  15.0

# %%
import matplotlib.pyplot as mtpl
a.plot()
# Out:
# City
# Chandigarh    AxesSubplot(0.125,0.125;0.775x0.755)
# Mathura       AxesSubplot(0.125,0.125;0.775x0.755)
# Pune          AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
